# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import metrics
wine= pd.read_table('wine.csv')
from sklearn import datasets
from sklearn import linear_model
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %%
wine= pd.read_table('wine.csv', sep=',')
wine.head(10)
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      3    12.20        3.03  2.32               19.0         96
# 1      1    13.30        1.72  2.14               17.0         94
# 2      1    13.87        1.90  2.80               19.4        107
# 3      1    13.39        1.77  2.62               16.1         93
# 4      2    11.65        1.67  2.62               26.0         88
# 5      2    12.70        3.87  2.40               23.0        101
# 6      1    13.88        1.89  2.59               15.0        101
# 7      3    12.45        3.03  2.64               27.0         97
# 8      3    14.16        2.51  2.48               20.0         91
# 9      1    14.02        1.68  2.21               16.0         96
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           1.25        0.49                  0.40             0.73
# 1           2.40        2.19                  0.27             1.35
# 2           2.95        2.97                  0.37             1.76
# 3           2.85        2.94                  0.34             1.45
# 4           1.92        1.61                  0.40             1.34
# 5           2.83        2.55                  0.43             1.95
# 6           3.25        3.56                  0.17             1.70
# 7           1.90        0.58                  0.63             1.14
# 8           1.68        0.70                  0.44             1.24
# 9           2.65        2.33                  0.26             1.98
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.50  0.66                          1.83      510
# 1             3.95  1.02                          2.77     1285
# 2             4.50  1.25                          3.40      915
# 3             4.80  0.92                          3.22     1195
# 4             2.60  1.36                          3.21      562
# 5             2.57  1.19                          3.13      463
# 6             5.43  0.88                          3.56     1095
# 7             7.50  0.67                          1.73      880
# 8             9.70  0.62                          1.71      660
# 9             4.70  1.04                          3.59     1035

# %%
X_scaled = preprocessing.scale(wine)

# %%
X_scaled
# Out:
# array([[ 1.22474487, -1.19526291,  0.60582574, ..., -1.25426748,
#         -0.93782812, -0.83711381],
#        [-1.22474487,  0.26787191, -0.5688373 , ...,  0.27183744,
#          0.32756676,  1.74410082],
#        [-1.22474487,  1.02604177, -0.40743322, ...,  1.24684892,
#          1.17565057,  0.511779  ],
#        ...,
#        [ 0.        , -1.51449233, -1.13375159, ...,  0.14466203,
#          0.81218608,  0.41519161],
#        [ 0.        , -1.18196169, -1.04408265, ...,  1.37402433,
#          0.73141619, -0.14434911],
#        [-1.22474487,  1.33196996, -0.17429399, ...,  1.24684892,
#          0.86603267,  2.49348571]])

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for col in wine.columns:
    wine[col] = labelencoder.fit_transform(wine[col])
 
wine.head()
# Out:
#    Class  Alcohol  Malic acid  Ash  Alcalinity of ash  Magnesium  \
# 0      2       12          78   30                 29         16
# 1      0       56          39   13                 18         14
# 2      0       85          51   64                 31         27
# 3      0       60          42   55                 13         13
# 4      1        2          36   55                 51          8
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0              3           3                    21                6
# 1             48          60                    10               33
# 2             67          87                    19               57
# 3             65          86                    17               42
# 4             34          46                    21               32
#
#    Color intensity  Hue  OD280/OD315 of diluted wines  Proline
# 0               69   12                            27       21
# 1               38   43                            59       86
# 2               50   63                            86       66
# 3               54   35                            80       83
# 4               10   68                            79       27

# %%
train_wine = wine.iloc[:round(len(wine)*.5)]
test_wine = wine.iloc[round(len(wine)*.5)+1:]

# %%
# Divide each into x and y
x_train = train_wine.loc[:, train_wine.columns != 'Class']
y_train = train_wine.Class

x_test = test_wine.loc[:, test_wine.columns != 'Class']
y_test = test_wine.Class

# %%
from sklearn import tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x_test
# Out:
#      Alcohol  Malic acid  Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 73        48          51   63                 50         34             43
# 74        97         101   45                  4         44             69
# 75        67          44   57                 29         29             47
# 76        47          98   32                 39         32             10
# 77        22          26   18                 29         50             53
# 78        40          77   36                 34         24              5
# 79        25          16   11                 34         23             12
# 80        41          92   57                 26         22             49
# 81        43          36   53                 53         48             75
# 82        65          90   17                 32          8             20
# 83        14          40   12                 29          2             21
# 84        18          93   34                 38          8             45
# 85        58           3   32                 18         29             54
# 86         1          56   42                 40          4             36
# 87         0          54   26                 23         18             70
# 88        89          32   26                 12         42             69
# 89        41          73   60                 38         16             15
# 90        71         110   31                 34         12             38
# 91        52          85   26                 25         18             28
# 92        15          21    8                 12          5             55
# 93        76          83   48                 34         27             29
# 94        15          74   20                 23          8             51
# 95        77          47   32                 16         21             58
# 96        39         108   43                 39          6             23
# 97        89          59   54                 21         38             57
# 98        70          69   59                 48         25             16
# 99        19           3    0                  0          8             37
# 100       30          88   32                 39         26             23
# 101       50         112   30                 41         13             25
# 102       45          55   68                 49         41             59
# ..       ...         ...  ...                ...        ...            ...
# 114       37          84   51                 41         26             21
# 115       70          35   32                 30         26             66
# 116        3          49    6                 12         17             19
# 117       75          46   32                 19         24             50
# 118       14          97   18                 25         31              7
# 119       66          80   55                 47         40              9
# 120       50          70   33                 34         37             21
# 121        5          39    4                 32          6             53
# 122       86         111   21                 34          2              0
# 123       19          13   50                 24         18             50
# 124       19          10   15                 29          7             77
# 125       65          35   22                 47          7             31
# 126       53         100   27                 20         23             60
# 127       74          15    6                 23         14             41
# 128        9          17   28                 46          0             43
# 129       17          64   42                 38         18             56
# 130       62          94   12                 27         10             51
# 131       29          27   24                 37          2              7
# 132       15          31   19                 35         23              1
# 133        4          58   62                 39         46             18
# 134       48           6    1                  8          1             68
# 135       14         109   48                 38          9              7
# 136       35          86   28                 32          8             12
# 137       84          25   58                 49          6             67
# 138        6           0   51                 23         14             43
# 139       45          42   11                 18         27             69
# 140       38          19   30                 23         39             14
# 141        7           8   28                 38         21             76
# 142       13          12    3                 17         49             30
# 143       90          60   28                 23         25             67
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity  Hue  \
# 73           34                     9               47               85    8
# 74           92                     4               71               60   32
# 75           72                    12               45               41   51
# 76           39                    17               24              103    4
# 77           64                    15               86               10   56
# 78           32                     7               10               66   18
# 79           10                    31               37               89    5
# 80           67                     8               68               50   44
# 81           84                     5               66               25   66
# 82            2                    34               13               75   25
# 83           56                    19               50               27   41
# 84           25                    29               20               90    3
# 85           35                    32                1               20   43
# 86           48                    28               33               14   41
# 87           63                     2               33               22   56
# 88           97                     7               72               73   50
# 89            4                    31                7               51   21
# 90           22                    27               18               48   34
# 91           23                    36               63              109    3
# 92           69                    12               58               16   62
# 93            8                    29                8               77   38
# 94           62                     8               69                3   55
# 95           83                    10               54               33   52
# 96           14                    27               12               90    1
# 97           70                    14               27               59   47
# 98           24                    20               45               98   18
# 99            9                    11                1                1   46
# 100          31                     2               11               57   22
# 101          13                    36               46               93    7
# 102          78                    27               64               29   54
# ..          ...                   ...              ...              ...  ...
# 114          11                    35               16               70   30
# 115          99                     6               65               84   50
# 116          43                    17               25               33   62
# 117          79                    23               67               34   62
# 118          21                    12               24               94   11
# 119          43                     6               27               97    6
# 120          16                    31               43              102    7
# 121          47                    19               39                2   36
# 122           0                    21                5               55    5
# 123          77                    19               71               51   59
# 124          94                     3               63               49   61
# 125          51                    10               19               32   39
# 126          75                    15               53               46   26
# 127          50                    15                6               33   62
# 128          45                    23               36                0   48
# 129          57                    17               31               14   24
# 130          78                    10               44               43   34
# 131          41                    34               49               19   38
# 132          28                    19               43               19   33
# 133          27                     1               47                8   37
# 134          98                     9               76               65   53
# 135           1                    31                8               35   19
# 136          15                    21               17              108   16
# 137          82                     5               63               26   68
# 138          61                     6               79               19   23
# 139          90                    11               70               58   31
# 140          33                     5               14               40   20
# 141          58                     0               52               21   40
# 142          34                     1               81               15   65
# 143         103                     6               80               76   63
#
#      OD280/OD315 of diluted wines  Proline
# 73                              3       10
# 74                             93       53
# 75                             64       78
# 76                              3       25
# 77                             51       68
# 78                              5       24
# 79                              9       36
# 80                             92       54
# 81                             91       69
# 82                             26       29
# 83                             76       21
# 84                             11       23
# 85                             30       52
# 86                             58       42
# 87                             68        3
# 88                            100       55
# 89                             43       31
# 90                             34       25
# 91                              8       40
# 92                             57       11
# 93                             26       42
# 94                             81        1
# 95                            103       73
# 96                             28       34
# 97                             97       88
# 98                             25       52
# 99                             26       23
# 100                             1       31
# 101                             7       49
# 102                            78       57
# ..                            ...      ...
# 114                            36       28
# 115                            65       94
# 116                            37       11
# 117                            64       70
# 118                            32       61
# 119                             2       19
# 120                            14       59
# 121                            44        8
# 122                             3        8
# 123                            42       41
# 124                            64        9
# 125                            60       16
# 126                            69       42
# 127                            45       35
# 128                            79       34
# 129                            85       12
# 130                            69       73
# 131                            35       18
# 132                            26       62
# 133                            40       34
# 134                            77       20
# 135                             0       48
# 136                            23       43
# 137                            75        7
# 138                            71       23
# 139                            83       64
# 140                             1       35
# 141                            73       65
# 142                            70       47
# 143                            76       93
#
# [71 rows x 13 columns]

# %%
y_test
# Out:
# 73     2
# 74     0
# 75     0
# 76     2
# 77     1
# 78     2
# 79     2
# 80     0
# 81     1
# 82     2
# 83     1
# 84     2
# 85     1
# 86     1
# 87     1
# 88     0
# 89     2
# 90     2
# 91     2
# 92     1
# 93     2
# 94     1
# 95     0
# 96     2
# 97     0
# 98     2
# 99     1
# 100    2
# 101    2
# 102    0
#       ..
# 114    2
# 115    0
# 116    1
# 117    0
# 118    2
# 119    2
# 120    2
# 121    1
# 122    2
# 123    1
# 124    1
# 125    1
# 126    0
# 127    1
# 128    1
# 129    1
# 130    0
# 131    1
# 132    1
# 133    1
# 134    1
# 135    2
# 136    2
# 137    1
# 138    1
# 139    0
# 140    2
# 141    1
# 142    1
# 143    0
# Name: Class, Length: 71, dtype: int64

# %%
data = x_train
target = y_train

# %%
clf = tree.DecisionTreeClassifier()
# Train Data
clf_train = clf.fit(data, target)

# %%
# get predictions
prd_clf = clf.predict(x_test)

# %%
print (metrics.accuracy_score(y_test,prd_clf))
# Out:
# 0.8169014084507042
